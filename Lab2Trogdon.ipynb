# %% [markdown]
# <a href="https://colab.research.google.com/github/TTrogdon22/Data-Science-/blob/main/Lab2Trogdon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
labels=['Frogs','Dogs','Cats', 'Birds']

# %%
sizes=[15,30,45,10]

# %%
explode=(0,0.1,0,0)

# %%
import matplotlib.pyplot as plt

# %%
fig1,ax1=plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
labels=('Sprite','Water','Cola','Fanta')

# %%
sizes=[25,25,25,25]

# %%
explode=(0.1,0,0,0)

# %%
fig1,ax1=plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
# Out:
# (-1.1742462120245876,
#  1.1035355339059327,
#  -1.1035355339059327,
#  1.1742462120245876)

# %%
name='Tiernan'

# %%
name
# Out:
# 'Tiernan'

# %%
f'Hello my name is {name}'
# Out:
# 'Hello my name is Tiernan'

# %%
f'{name} went to the store'
# Out:
# 'Tiernan went to the store'

# %% [markdown]
# #Files

# %%
f=open("Hello.txt",'w')

name="Tiernan"

data= f"Hello {name}"

print(data, file=f)

f.close()

# %%
f=open("Hello.txt","r")

lines=f.readlines()

print(lines)

f.close()
# Out:
# ['Hello Tiernan\n']

# %% [markdown]
# #Coin Flip

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.7544443729556232

# %% [markdown]
# random.random gives you a random number between 0 and 1

# %%
for index in range (10):
  print(index, np.random.random())
# Out:
# 0 0.4151759579166193
# 1 0.6198559905083441
# 2 0.5946939288450318
# 3 0.8574941099690264
# 4 0.049694324934672185
# 5 0.1981692498535519
# 6 0.7020131457990127
# 7 0.4092165839546026
# 8 0.12415345520261545
# 9 0.026549161479462846

# %%
for i in range (10):
  print(i, np.random.random())
# Out:
# 0 0.9526659939024256
# 1 0.9550554020551736
# 2 0.3862077871303332
# 3 0.5056773559614541
# 4 0.16775688653308674
# 5 0.6458534671604788
# 6 0.08294068160535972
# 7 0.6169132676214514
# 8 0.1576967161823134
# 9 0.20574113501526226

# %% [markdown]
# i can also work as index

# %%
for step in range (10):
  print(step, "Hello your name is: ", np.random.random())
# Out:
# 0 Hello your name is:  0.5587582008595484
# 1 Hello your name is:  0.9634121283077532
# 2 Hello your name is:  0.17732657734439272
# 3 Hello your name is:  0.7052627054689754
# 4 Hello your name is:  0.21858155915007227
# 5 Hello your name is:  0.7923305616666089
# 6 Hello your name is:  0.22300106504847228
# 7 Hello your name is:  0.45830284448688696
# 8 Hello your name is:  0.450435057460703
# 9 Hello your name is:  0.8891768335840089

# %%
np.random.random()>.5
# Out:
# False

# %%
for flip in range(10):
   print(np.random.random() > 0.5)
# Out:
# True
# True
# False
# True
# False
# False
# False
# True
# True
# False

# %%
for flip in range(10):
   coin=np.random.random() > 0.5
   if coin == True:
     print("Heads")
   else:
       print("Tails")
# Out:
# Tails
# Heads
# Tails
# Tails
# Tails
# Tails
# Heads
# Tails
# Heads
# Heads

# %% [markdown]
# #Functions

# %%
def flip_coin():
  coin=np.random.random() > 0.5
  if  coin == True:
     print("Heads")
  else:
       print("Tails")

# %%
flip_coin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1e7394609c8a> in <module>
# ----> 1 flip_coin()
#
# <ipython-input-23-73868b8aaa53> in flip_coin()
#       1 def flip_coin():
# ----> 2   coin=np.random.random() > 0.5
#       3   if  coin == True:
#       4      print("Heads")
#       5   else:
#
# NameError: name 'np' is not defined

# %%
for i in range(10):
  flip_coin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a02db8f653c5> in <module>
#       1 for i in range(10):
# ----> 2   flip_coin()
#
# <ipython-input-23-73868b8aaa53> in flip_coin()
#       1 def flip_coin():
# ----> 2   coin=np.random.random() > 0.5
#       3   if  coin == True:
#       4      print("Heads")
#       5   else:
#
# NameError: name 'np' is not defined

# %% [markdown]
# #Graphics

# %%
from IPython.core.display import display, HTML

# %%
display(HTML('<h1>Hello World</h1>'))
# Out:
# <h1>Hello World</h1>

# %%
def coin():
  return np.random.randint(2)

# %%
display(HTML('<img src="https://random-ize.com/coin-flip/us-quarter/us-quarter-front.jpg">'))
# Out:
# <img src="https://random-ize.com/coin-flip/us-quarter/us-quarter-front.jpg">

# %%
coin_heads_url= "https://random-ize.com/coin-flip/us-quarter/us-quarter-front.jpg"
coin_tails_url="https://random-ize.com/coin-flip/us-quarter/us-quarter-back.jpg"

# %%
display(HTML('<img src="https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg">'))
# Out:
# <img src="https://m.media-amazon.com/images/I/51bcZy+HZpL._AC_.jpg">

# %%
def show_img(img):
  display(HTML('<img src=' + img + '>'))

# %%
def flip_coin():

    if coin():
        show_img(heads)
    else:
        show_img(tails)

# %%
coin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-696b104313ad> in <module>
# ----> 1 coin()
#
# <ipython-input-14-7fbee108a5cc> in coin()
#       1 def coin():
# ----> 2   return np.random.randint(2)
#
# NameError: name 'np' is not defined

# %%
show_img(heads)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2b9c54e09a78> in <module>
# ----> 1 show_img(heads)
#
# NameError: name 'heads' is not defined

# %%
show_img(tails)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-95ee3c65e2ed> in <module>
# ----> 1 show_img(tails)
#
# NameError: name 'tails' is not defined

# %%
flip_coin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1e7394609c8a> in <module>
# ----> 1 flip_coin()
#
# NameError: name 'flip_coin' is not defined

# %%
for i in range(5):
    flip_coin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3b342d04e184> in <module>
#       1 for i in range(5):
# ----> 2     flip_coin()
#
# <ipython-input-7-0598c0c09997> in flip_coin()
#       1 def flip_coin():
#       2
# ----> 3     if coin():
#       4         show_img(heads)
#       5     else:
#
# <ipython-input-14-7fbee108a5cc> in coin()
#       1 def coin():
# ----> 2   return np.random.randint(2)
#
# NameError: name 'np' is not defined

# %%
show_img(heads)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b9c54e09a78> in <module>
# ----> 1 show_img(heads)
#
# NameError: name 'show_img' is not defined

# %%
flip_coin()
